# %%
import pip
pip.main(['install', 'tabulate'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: tabulate in c:\users\bryso\documents\new folder\lib\site-packages (0.8.9)
# 0

# %%
import numpy as np
from IPython.display import HTML, display
import tabulate

# %%
#State abbreviations: https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States#States
#Cases: https://covid.cdc.gov/covid-data-tracker/#cases_totalcases
#Vaccinations: https://usafacts.org/visualizations/covid-vaccine-tracker-states/

# %%
#Data

# %%
caseDate = "11-6-2021"

# %%
vaccDate = "11-5-2021"

# %%
#Alabama Cases

#State
ALstate = "AL"

#Cases in the last 7 days
AL7case = "04087"

#Cases in the last 7 days per 100k people
AL7case100 = "083.4"

#Total Cases
ALcase = "0835740"

#Total Cases per 100k people
ALcase100 = "17045"

#Alabama Vaccinations

#% with 1 dose
ALvacc1per = "54.83"

#1 dose
ALvacc1 = "02688481"

#% with 2 doses
ALvacc2per = "45.01"

#2 doses
ALvacc2 = "02207077"

#Array of AL data
AL = np.array([ALstate, AL7case, AL7case100, ALcase, ALcase100, ALvacc1per, ALvacc1, ALvacc2per, ALvacc2])

# %%
#Alaska Cases

#State
AKstate = "AK"

#Cases in the last 7 days
AK7case = "04177"

#Cases in the last 7 days per 100k people
AK7case100 = "571.0"

#Total Cases
AKcase = "0136822"

#Total Cases per 100k people
AKcase100 = "18703"

#Alaska Vaccinations

#% with 1 dose
AKvacc1per = "59.80"

#1 dose
AKvacc1 = "00437494"

#% with 2 doses
AKvacc2per = "52.91"

#2 doses
AKvacc2 = "00387028"

#Array of AK data
AK = np.array([AKstate, AK7case, AK7case100, AKcase, AKcase100, AKvacc1per, AKvacc1, AKvacc2per, AKvacc2])

# %%
#Arizona Cases

#State
AZstate = "AZ"

#Cases in the last 7 days
AZ7case = "19668"

#Cases in the last 7 days per 100k people
AZ7case100 = "270.2"

#Total Cases
AZcase = "1182885"

#Total Cases per 100k people
AZcase100 = "16251"

#Arizona Vaccinations

#% with 1 dose
AZvacc1per = "61.53"

#1 dose
AZvacc1 = "04478629"

#% with 2 doses
AZvacc2per = "53.37"

#2 doses
AZvacc2 = "03884433"

#Array of AZ data
AZ = np.array([AZstate, AZ7case, AZ7case100, AZcase, AZcase100, AZvacc1per, AZvacc1, AZvacc2per, AZvacc2])

# %%
#Arkansas Cases

#State
ARstate = "AR"

#Cases in the last 7 days
AR7case = "02994"

#Cases in the last 7 days per 100k people
AR7case100 = "099.2"

#Total Cases
ARcase = "0515524"

#Total Cases per 100k people
ARcase100 = "17083"

#Arkansas Vaccinations

#% with 1 dose
ARvacc1per = "58.32"

#1 dose
ARvacc1 = "01760122"

#% with 2 doses
ARvacc2per = "48.27"

#2 doses
ARvacc2 = "01456597"

#Array of AR data
AR = np.array([ARstate, AR7case, AR7case100, ARcase, ARcase100, ARvacc1per, ARvacc1, ARvacc2per, ARvacc2])

# %%
#California Cases

#State
CAstate = "CA"

#Cases in the last 7 days
CA7case = "44801"

#Cases in the last 7 days per 100k people
CA7case100 = "113.4"

#Total Cases
CAcase = "4937188"

#Total Cases per 100k people
CAcase100 = "12495"

#California Vaccinations

#% with 1 dose
CAvacc1per = "75.01"

#1 dose
CAvacc1 = "29638088"

#% with 2 doses
CAvacc2per = "61.62"

#2 doses
CAvacc2 = "24347393"

#Array of CA data
CA = np.array([CAstate, CA7case, CA7case100, CAcase, CAcase100, CAvacc1per, CAvacc1, CAvacc2per, CAvacc2])

# %%
#Colorado Cases

#State
COstate = "CO"

#Cases in the last 7 days
CO7case = "19992"

#Cases in the last 7 days per 100k people
CO7case100 = "347.2"

#Total Cases
COcase = "0760453"

#Total Cases per 100k people
COcase100 = "13205"

#Colorado Vaccinations

#% with 1 dose
COvacc1per = "68.01"

#1 dose
COvacc1 = "03916273"

#% with 2 doses
COvacc2per = "61.90"

#2 doses
COvacc2 = "03564615"

#Array of CO data
CO = np.array([COstate, CO7case, CO7case100, COcase, COcase100, COvacc1per, COvacc1, COvacc2per, COvacc2])

# %%
#Connecticut Cases

#State
CTstate = "CT"

#Cases in the last 7 days
CT7case = "02386"

#Cases in the last 7 days per 100k people
CT7case100 = "066.9"

#Total Cases
CTcase = "0404969"

#Total Cases per 100k people
CTcase100 = "11359"

#Connecticut Vaccinations

#% with 1 dose
CTvacc1per = "79.63"

#1 dose
CTvacc1 = "02839105"

#% with 2 doses
CTvacc2per = "70.96"

#2 doses
CTvacc2 = "02529755"

#Array of CT data
CT = np.array([CTstate, CT7case, CT7case100, CTcase, CTcase100, CTvacc1per, CTvacc1, CTvacc2per, CTvacc2])

# %%
#Delaware Cases

#State
DEstate = "DE"

#Cases in the last 7 days
DE7case = "01767"

#Cases in the last 7 days per 100k people
DE7case100 = "181.5"

#Total Cases
DEcase = "0145330"

#Total Cases per 100k people
DEcase100 = "14925"

#Delaware Vaccinations

#% with 1 dose
DEvacc1per = "69.52"

#1 dose
DEvacc1 = "00676938"

#% with 2 doses
DEvacc2per = "60.15"

#2 doses
DEvacc2 = "00585705"

#Array of DE data
DE = np.array([DEstate, DE7case, DE7case100, DEcase, DEcase100, DEvacc1per, DEvacc1, DEvacc2per, DEvacc2])

# %%
#District of Columbia Cases
#State
DCstate = "DC"

#Cases in the last 7 days
DC7case = "00559"

#Cases in the last 7 days per 100k people
DC7case100 = "079.2"

#Total Cases
DCcase = "0064799"

#Total Cases per 100k people
DCcase100 = "09182"

#District of Columbia Vaccinations

#% with 1 dose
DCvacc1per = "75.64"

#1 dose
DCvacc1 = "00533815"

#% with 2 doses
DCvacc2per = "62.90"

#2 doses
DCvacc2 = "00443934"

#Array of DC data
DC = np.array([DCstate, DC7case, DC7case100, DCcase, DCcase100, DCvacc1per, DCvacc1, DCvacc2per, DCvacc2])

# %%
#Florida Cases

#State
FLstate = "FL"

#Cases in the last 7 days
FL7case = "10764"

#Cases in the last 7 days per 100k people
FL7case100 = "050.1"

#Total Cases
FLcase = "3659255"

#Total Cases per 100k people
FLcase100 = "17037"

#Florida Vaccinations

#% with 1 dose
FLvacc1per = "69.40"

#1 dose
FLvacc1 = "14905682"

#% with 2 doses
FLvacc2per = "59.98"

#2 doses
FLvacc2 = "12882180"

#Array of FL data
FL = np.array([FLstate, FL7case, FL7case100, FLcase, FLcase100, FLvacc1per, FLvacc1, FLvacc2per, FLvacc2])

# %%
#Georgia Cases

#State
GAstate = "GA"

#Cases in the last 7 days
GA7case = "06943"

#Cases in the last 7 days per 100k people
GA7case100 = "065.4"

#Total Cases
GAcase = "1641036"

#Total Cases per 100k people
GAcase100 = "15456"

#Georgia Vaccinations

#% with 1 dose
GAvacc1per = "57.17"

#1 dose
GAvacc1 = "06070072"

#% with 2 doses
GAvacc2per = "48.50"

#2 doses
GAvacc2 = "05149397"

#Array of GA data
GA = np.array([GAstate, GA7case, GA7case100, GAcase, GAcase100, GAvacc1per, GAvacc1, GAvacc2per, GAvacc2])

# %%
#Hawaii Cases

#State
HIstate = "HI"

#Cases in the last 7 days
HI7case = "00760"

#Cases in the last 7 days per 100k people
HI7case100 = "053.7"

#Total Cases
HIcase = "0082071"

#Total Cases per 100k people
HIcase100 = "05796"

#Hawaii Vaccinations

#% with 1 dose
HIvacc1per = "79.26"

#1 dose
HIvacc1 = "01122158"

#% with 2 doses
HIvacc2per = "60.02"

#2 doses
HIvacc2 = "00849770"

#Array of HI data
HI = np.array([HIstate, HI7case, HI7case100, HIcase, HIcase100, HIvacc1per, HIvacc1, HIvacc2per, HIvacc2])

# %%
#Idaho Cases

#State
IDstate = "ID"

#Cases in the last 7 days
ID7case = "05078"

#Cases in the last 7 days per 100k people
ID7case100 = "284.2"

#Total Cases
IDcase = "0295950"

#Total Cases per 100k people
IDcase100 = "16561"

#Idaho Vaccinations

#% with 1 dose
IDvacc1per = "49.41"

#1 dose
IDvacc1 = "00882949"

#% with 2 doses
IDvacc2per = "44.16"

#2 doses
IDvacc2 = "00789098"

#Array of ID data
ID = np.array([IDstate, ID7case, ID7case100, IDcase, IDcase100, IDvacc1per, IDvacc1, IDvacc2per, IDvacc2])

# %%
#Illinois Cases

#State
ILstate = "IL"

#Cases in the last 7 days
IL7case = "17462"

#Cases in the last 7 days per 100k people
IL7case100 = "137.8"

#Total Cases
ILcase = "1712986"

#Total Cases per 100k people
ILcase100 = "13518"

#Illinois Vaccinations

#% with 1 dose
ILvacc1per = "66.08"

#1 dose
ILvacc1 = "08373651"

#% with 2 doses
ILvacc2per = "60.74"

#2 doses
ILvacc2 = "07696802"

#Array of IL data
IL = np.array([ILstate, IL7case, IL7case100, ILcase, ILcase100, ILvacc1per, ILvacc1, ILvacc2per, ILvacc2])

# %%
#Indiana Cases

#State
INstate = "IN"

#Cases in the last 7 days
IN7case = "11653"

#Cases in the last 7 days per 100k people
IN7case100 = "173.1"

#Total Cases
INcase = "1030291"

#Total Cases per 100k people
INcase100 = "15304"

#Indiana Vaccinations

#% with 1 dose
INvacc1per = "53.99"

#1 dose
INvacc1 = "03635009"

#% with 2 doses
INvacc2per = "49.99"

#2 doses
INvacc2 = "03365638"

#Array of IN data
IN = np.array([INstate, IN7case, IN7case100, INcase, INcase100, INvacc1per, INvacc1, INvacc2per, INvacc2])

# %%
#Iowa Cases

#State
IAstate = "IA"

#Cases in the last 7 days
IA7case = "08275"

#Cases in the last 7 days per 100k people
IA7case100 = "262.3"

#Total Cases
IAcase = "0494407"

#Total Cases per 100k people
IAcase100 = "15670"

#Iowa Vaccinations

#% with 1 dose
IAvacc1per = "59.98"

#1 dose
IAvacc1 = "01892307"

#% with 2 doses
IAvacc2per = "55.80"

#2 doses
IAvacc2 = "01760389"

#Array of IA data
IA = np.array([IAstate, IA7case, IA7case100, IAcase, IAcase100, IAvacc1per, IAvacc1, IAvacc2per, IAvacc2])

# %%
#Kansas Cases

#State
KSstate = "KS"

#Cases in the last 7 days
KS7case = "05657"

#Cases in the last 7 days per 100k people
KS7case100 = "194.2"

#Total Cases
KScase = "0440303"

#Total Cases per 100k people
KScase100 = "15114"

#Kansas Vaccinations

#% with 1 dose
KSvacc1per = "62.96"

#1 dose
KSvacc1 = "01834175"

#% with 2 doses
KSvacc2per = "53.45"

#2 doses
KSvacc2 = "01557100"

#Array of KS data
KS = np.array([KSstate, KS7case, KS7case100, KScase, KScase100, KSvacc1per, KSvacc1, KSvacc2per, KSvacc2])

# %%
#Kentucky Cases

#State
KYstate = "KY"

#Cases in the last 7 days
KY7case = "07829"

#Cases in the last 7 days per 100k people
KY7case100 = "175.2"

#Total Cases
KYcase = "0750985"

#Total Cases per 100k people
KYcase100 = "16809"

#Kentucky Vaccinations

#% with 1 dose
KYvacc1per = "57.78"

#1 dose
KYvacc1 = "02581520"

#% with 2 doses
KYvacc2per = "50.96"

#2 doses
KYvacc2 = "02276697"

#Array of KY data
KY = np.array([KYstate, KY7case, KY7case100, KYcase, KYcase100, KYvacc1per, KYvacc1, KYvacc2per, KYvacc2])

# %%
#Louisiana Cases

#State
LAstate = "LA"

#Cases in the last 7 days
LA7case = "03378"

#Cases in the last 7 days per 100k people
LA7case100 = "072.7"

#Total Cases
LAcase = "0761849"

#Total Cases per 100k people
LAcase100 = "16388"

#Louisiana Vaccinations

#% with 1 dose
LAvacc1per = "54.06"

#1 dose
LAvacc1 = "02513209"

#% with 2 doses
LAvacc2per = "47.87"

#2 doses
LAvacc2 = "02225163"

#Array of LA data
LA = np.array([LAstate, LA7case, LA7case100, LAcase, LAcase100, LAvacc1per, LAvacc1, LAvacc2per, LAvacc2])

# %%
#Maine Cases

#State
MEstate = "ME"

#Cases in the last 7 days
ME7case = "04066"

#Cases in the last 7 days per 100k people
ME7case100 = "302.5"

#Total Cases
MEcase = "0107737"

#Total Cases per 100k people
MEcase100 = "08015"

#Maine Vaccinations

#% with 1 dose
MEvacc1per = "77.36"

#1 dose
MEvacc1 = "01039835"

#% with 2 doses
MEvacc2per = "70.91"

#2 doses
MEvacc2 = "00953207"

#Array of ME data
ME = np.array([MEstate, ME7case, ME7case100, MEcase, MEcase100, MEvacc1per, MEvacc1, MEvacc2per, MEvacc2])

# %%
#Maryland Cases

#State
MDstate = "MD"

#Cases in the last 7 days
MD7case = "04721"

#Cases in the last 7 days per 100k people
MD7case100 = "078.1"

#Total Cases
MDcase = "0565355"

#Total Cases per 100k people
MDcase100 = "09351"

#Maryland Vaccinations

#% with 1 dose
MDvacc1per = "73.16"

#1 dose
MDvacc1 = "04423295"

#% with 2 doses
MDvacc2per = "66.17"

#2 doses
MDvacc2 = "04000327"

#Array of MD data
MD = np.array([MDstate, MD7case, MD7case100, MDcase, MDcase100, MDvacc1per, MDvacc1, MDvacc2per, MDvacc2])

# %%
#Massachusetts Cases

#State
MAstate = "MA"

#Cases in the last 7 days
MA7case = "09558"

#Cases in the last 7 days per 100k people
MA7case100 = "138.7"

#Total Cases
MAcase = "0861480"

#Total Cases per 100k people
MAcase100 = "12499"

#Massachusetts Vaccinations

#% with 1 dose
MAvacc1per = "80.80"

#1 dose
MAvacc1 = "05568932"

#% with 2 doses
MAvacc2per = "69.91"

#2 doses
MAvacc2 = "04818711"

#Array of MA data
MA = np.array([MAstate, MA7case, MA7case100, MAcase, MAcase100, MAvacc1per, MAvacc1, MAvacc2per, MAvacc2])

# %%
#Michigan Cases

#State
MIstate = "MI"

#Cases in the last 7 days
MI7case = "34552"

#Cases in the last 7 days per 100k people
MI7case100 = "346.0"

#Total Cases
MIcase = "1309655"

#Total Cases per 100k people
MIcase100 = "13114"

#Michigan Vaccinations

#% with 1 dose
MIvacc1per = "58.52"

#1 dose
MIvacc1 = "05844248"

#% with 2 doses
MIvacc2per = "53.70"

#2 doses
MIvacc2 = "05362760"

#Array of MI data
MI = np.array([MIstate, MI7case, MI7case100, MIcase, MIcase100, MIvacc1per, MIvacc1, MIvacc2per, MIvacc2])

# %%
#Minnesota Cases

#State
MNstate = "MN"

#Cases in the last 7 days
MN7case = "19504"

#Cases in the last 7 days per 100k people
MN7case100 = "345.8"

#Total Cases
MNcase = "0815008"

#Total Cases per 100k people
MNcase100 = "14451"

#Minnesota Vaccinations

#% with 1 dose
MNvacc1per = "65.64"

#1 dose
MNvacc1 = "03701677"

#% with 2 doses
MNvacc2per = "61.46"

#2 doses
MNvacc2 = "03466294"

#Array of MN data
MN = np.array([MNstate, MN7case, MN7case100, MNcase, MNcase100, MNvacc1per, MNvacc1, MNvacc2per, MNvacc2])

# %%
#Mississippi Cases

#State
MSstate = "MS"

#Cases in the last 7 days
MS7case = "02238"

#Cases in the last 7 days per 100k people
MS7case100 = "075.2"

#Total Cases
MScase = "0506556"

#Total Cases per 100k people
MScase100 = "17020"

#Mississippi Vaccinations

#% with 1 dose
MSvacc1per = "52.39"

#1 dose
MSvacc1 = "01559285"

#% with 2 doses
MSvacc2per = "46.01"

#2 doses
MSvacc2 = "01369214"

#Array of MS data
MS = np.array([MSstate, MS7case, MS7case100, MScase, MScase100, MSvacc1per, MSvacc1, MSvacc2per, MSvacc2])

# %%
#Missouri Cases

#State
MOstate = "MO"

#Cases in the last 7 days
MO7case = "07518"

#Cases in the last 7 days per 100k people
MO7case100 = "122.5"

#Total Cases
MOcase = "0861591"

#Total Cases per 100k people
MOcase100 = "14038"

#Missouri Vaccinations

#% with 1 dose
MOvacc1per = "57.17"

#1 dose
MOvacc1 = "03508567"

#% with 2 doses
MOvacc2per = "49.97"

#2 doses
MOvacc2 = "03066966"

#Array of MO data
MO = np.array([MOstate, MO7case, MO7case100, MOcase, MOcase100, MOvacc1per, MOvacc1, MOvacc2per, MOvacc2])

# %%
#Montana Cases

#State
MTstate = "MT"

#Cases in the last 7 days
MT7case = "04605"

#Cases in the last 7 days per 100k people
MT7case100 = "430.9"

#Total Cases
MTcase = "0180452"

#Total Cases per 100k people
MTcase100 = "16884"

#Montana Vaccinations

#% with 1 dose
MTvacc1per = "57.27"

#1 dose
MTvacc1 = "00612140"

#% with 2 doses
MTvacc2per = "50.77"

#2 doses
MTvacc2 = "00542662"

#Array of MT data
MT = np.array([MTstate, MT7case, MT7case100, MTcase, MTcase100, MTvacc1per, MTvacc1, MTvacc2per, MTvacc2])

# %%
#Nebraska Cases

#State
NEstate = "NE"

#Cases in the last 7 days
NE7case = "04516"

#Cases in the last 7 days per 100k people
NE7case100 = "233.5"

#Total Cases
NEcase = "0289282"

#Total Cases per 100k people
NEcase100 = "14954"

#Nebraska Vaccinations

#% with 1 dose
NEvacc1per = "61.29"

#1 dose
NEvacc1 = "01185648"

#% with 2 doses
NEvacc2per = "56.46"

#2 doses
NEvacc2 = "01092256"

#Array of NE data
NE = np.array([NEstate, NE7case, NE7case100, NEcase, NEcase100, NEvacc1per, NEvacc1, NEvacc2per, NEvacc2])

# %%
#Nevada Cases

#State
NVstate = "NV"

#Cases in the last 7 days
NV7case = "05841"

#Cases in the last 7 days per 100k people
NV7case100 = "189.6"

#Total Cases
NVcase = "0455163"

#Total Cases per 100k people
NVcase100 = "14777"

#Nevada Vaccinations

#% with 1 dose
NVvacc1per = "63.77"

#1 dose
NVvacc1 = "01964166"

#% with 2 doses
NVvacc2per = "53.24"

#2 doses
NVvacc2 = "01640000"

#Array of NV data
NV = np.array([NVstate, NV7case, NV7case100, NVcase, NVcase100, NVvacc1per, NVvacc1, NVvacc2per, NVvacc2])

# %%
#New Hampshire Cases

#State
NHstate = "NH"

#Cases in the last 7 days
NH7case = "04807"

#Cases in the last 7 days per 100k people
NH7case100 = "353.5"

#Total Cases
NHcase = "0139324"

#Total Cases per 100k people
NHcase100 = "10247"

#New Hampshire Vaccinations

#% with 1 dose
NHvacc1per = "78.10"

#1 dose
NHvacc1 = "01061907"

#% with 2 doses
NHvacc2per = "63.25"

#2 doses
NHvacc2 = "00859959"

#Array of NH data
NH = np.array([NHstate, NH7case, NH7case100, NHcase, NHcase100, NHvacc1per, NHvacc1, NHvacc2per, NHvacc2])

# %%
#New Jersey Cases

#State
NJstate = "NJ"

#Cases in the last 7 days
NJ7case = "08668"

#Cases in the last 7 days per 100k people
NJ7case100 = "097.6"

#Total Cases
NJcase = "1205140"

#Total Cases per 100k people
NJcase100 = "13568"

#New Jersey Vaccinations

#% with 1 dose
NJvacc1per = "75.50"

#1 dose
NJvacc1 = "06706121"

#% with 2 doses
NJvacc2per = "66.62"

#2 doses
NJvacc2 = "05917377"

#Array of NJ data
NJ = np.array([NJstate, NJ7case, NJ7case100, NJcase, NJcase100, NJvacc1per, NJvacc1, NJvacc2per, NJvacc2])

# %%
#New Mexico Cases

#State
NMstate = "NM"

#Cases in the last 7 days
NM7case = "07533"

#Cases in the last 7 days per 100k people
NM7case100 = "359.3"

#Total Cases
NMcase = "0282742"

#Total Cases per 100k people
NMcase100 = "13484"

#New Mexico Vaccinations

#% with 1 dose
NMvacc1per = "72.63"

#1 dose
NMvacc1 = "01522958"

#% with 2 doses
NMvacc2per = "62.38"

#2 doses
NMvacc2 = "01308007"

#Array of NM data
NM = np.array([NMstate, NM7case, NM7case100, NMcase, NMcase100, NMvacc1per, NMvacc1, NMvacc2per, NMvacc2])

# %%
#New York Cases

#State
NYstate = "NY"

#Cases in the last 7 days
NY7case = "27496"

#Cases in the last 7 days per 100k people
NY7case100 = "141.3"

#Total Cases
NYcase = "2581607"

#Total Cases per 100k people
NYcase100 = "13271"

#New York Vaccinations

#% with 1 dose
NYvacc1per = "74.77"

#1 dose
NYvacc1 = "14544831"

#% with 2 doses
NYvacc2per = "67.02"

#2 doses
NYvacc2 = "13038415"

#Array of NY data
NY = np.array([NYstate, NY7case, NY7case100, NYcase, NYcase100, NYvacc1per, NYvacc1, NYvacc2per, NYvacc2])

# %%
#North Carolina Cases

#State
NCstate = "NC"

#Cases in the last 7 days
NC7case = "12139"

#Cases in the last 7 days per 100k people
NC7case100 = "115.7"

#Total Cases
NCcase = "1489653"

#Total Cases per 100k people
NCcase100 = "14203"

#North Carolina Vaccinations

#% with 1 dose
NCvacc1per = "65.12"

#1 dose
NCvacc1 = "06830289"

#% with 2 doses
NCvacc2per = "53.08"

#2 doses
NCvacc2 = "05566902"

#Array of NC data
NC = np.array([NCstate, NC7case, NC7case100, NCcase, NCcase100, NCvacc1per, NCvacc1, NCvacc2per, NCvacc2])

# %%
#North Dakota Cases

#State
NDstate = "ND"

#Cases in the last 7 days
ND7case = "03553"

#Cases in the last 7 days per 100k people
ND7case100 = "466.2"

#Total Cases
NDcase = "0151644"

#Total Cases per 100k people
NDcase100 = "19899"

#North Dakota Vaccinations

#% with 1 dose
NDvacc1per = "55.30"

#1 dose
NDvacc1 = "00421444"

#% with 2 doses
NDvacc2per = "47.77"

#2 doses
NDvacc2 = "00364057"

#Array of ND data
ND = np.array([NDstate, ND7case, ND7case100, NDcase, NDcase100, NDvacc1per, NDvacc1, NDvacc2per, NDvacc2])

# %%
#Ohio Cases

#State
OHstate = "OH"

#Cases in the last 7 days
OH7case = "25553"

#Cases in the last 7 days per 100k people
OH7case100 = "218.6"

#Total Cases
OHcase = "1565043"

#Total Cases per 100k people
OHcase100 = "13389"

#Ohio Vaccinations

#% with 1 dose
OHvacc1per = "56.07"

#1 dose
OHvacc1 = "06554646"

#% with 2 doses
OHvacc2per = "52.06"

#2 doses
OHvacc2 = "06085647"

#Array of OH data
OH = np.array([OHstate, OH7case, OH7case100, OHcase, OHcase100, OHvacc1per, OHvacc1, OHvacc2per, OHvacc2])

# %%
#Oklahoma Cases

#State
OKstate = "OK"

#Cases in the last 7 days
OK7case = "04107"

#Cases in the last 7 days per 100k people
OK7case100 = "103.8"

#Total Cases
OKcase = "0648791"

#Total Cases per 100k people
OKcase100 = "16396"

#Oklahoma Vaccinations

#% with 1 dose
OKvacc1per = "59.94"

#1 dose
OKvacc1 = "02371929"

#% with 2 doses
OKvacc2per = "50.35"

#2 doses
OKvacc2 = "01992503"

#Array of OK data
OK = np.array([OKstate, OK7case, OK7case100, OKcase, OKcase100, OKvacc1per, OKvacc1, OKvacc2per, OKvacc2])

# %%
#Oregon Cases

#State
ORstate = "OR"

#Cases in the last 7 days
OR7case = "07084"

#Cases in the last 7 days per 100k people
OR7case100 = "168.0"

#Total Cases
ORcase = "0372137"

#Total Cases per 100k people
ORcase100 = "08823"

#Oregon Vaccinations

#% with 1 dose
ORvacc1per = "68.69"

#1 dose
ORvacc1 = "02897123"

#% with 2 doses
ORvacc2per = "63.10"

#2 doses
ORvacc2 = "02661407"

#Array of OR data
OR = np.array([ORstate, OR7case, OR7case100, ORcase, ORcase100, ORvacc1per, ORvacc1, ORvacc2per, ORvacc2])

# %%
#Pennsylvania Cases

#State
PAstate = "PA"

#Cases in the last 7 days
PA7case = "28017"

#Cases in the last 7 days per 100k people
PA7case100 = "218.9"

#Total Cases
PAcase = "1585476"

#Total Cases per 100k people
PAcase100 = "12385"

#Pennsylvania Vaccinations

#% with 1 dose
PAvacc1per = "79.13"

#1 dose
PAvacc1 = "10130128"

#% with 2 doses
PAvacc2per = "60.89"

#2 doses
PAvacc2 = "07794577"

#Array of PA data
PA = np.array([PAstate, PA7case, PA7case100, PAcase, PAcase100, PAvacc1per, PAvacc1, PAvacc2per, PAvacc2])

# %%
#Rhode Island Cases

#State
RIstate = "RI"

#Cases in the last 7 days
RI7case = "01653"

#Cases in the last 7 days per 100k people
RI7case100 = "156.0"

#Total Cases
RIcase = "0181079"

#Total Cases per 100k people
RIcase100 = "17093"

#Rhode Island Vaccinations

#% with 1 dose
RIvacc1per = "78.69"

#1 dose
RIvacc1 = "00833615"

#% with 2 doses
RIvacc2per = "71.21"

#2 doses
RIvacc2 = "00754331"

#Array of RI data
RI = np.array([RIstate, RI7case, RI7case100, RIcase, RIcase100, RIvacc1per, RIvacc1, RIvacc2per, RIvacc2])

# %%
#South Carolina Cases

#State
SCstate = "SC"

#Cases in the last 7 days
SC7case = "04587"

#Cases in the last 7 days per 100k people
SC7case100 = "089.1"

#Total Cases
SCcase = "0902016"

#Total Cases per 100k people
SCcase100 = "17519"

#South Carolina Vaccinations

#% with 1 dose
SCvacc1per = "57.94"

#1 dose
SCvacc1 = "02983292"

#% with 2 doses
SCvacc2per = "50.25"

#2 doses
SCvacc2 = "02587217"

#Array of SC data
SC = np.array([SCstate, SC7case, SC7case100, SCcase, SCcase100, SCvacc1per, SCvacc1, SCvacc2per, SCvacc2])

# %%
#South Dakota Cases

#State
SDstate = "SD"

#Cases in the last 7 days
SD7case = "02513"

#Cases in the last 7 days per 100k people
SD7case100 = "284.1"

#Total Cases
SDcase = "0156995"

#Total Cases per 100k people
SDcase100 = "17746"

#South Dakota Vaccinations

#% with 1 dose
SDvacc1per = "62.69"

#1 dose
SDvacc1 = "00554587"

#% with 2 doses
SDvacc2per = "53.19"

#2 doses
SDvacc2 = "00470541"

#Array of SD data
SD = np.array([SDstate, SD7case, SD7case100, SDcase, SDcase100, SDvacc1per, SDvacc1, SDvacc2per, SDvacc2])

# %%
#Tennessee Cases

#State
TNstate = "TN"

#Cases in the last 7 days
TN7case = "06724"

#Cases in the last 7 days per 100k people
TN7case100 = "098.5"

#Total Cases
TNcase = "1286713"

#Total Cases per 100k people
TNcase100 = "18841"

#Tennessee Vaccinations

#% with 1 dose
TNvacc1per = "54.82"

#1 dose
TNvacc1 = "03743419"

#% with 2 doses
TNvacc2per = "47.93"

#2 doses
TNvacc2 = "03273222"

#Array of TN data
TN = np.array([TNstate, TN7case, TN7case100, TNcase, TNcase100, TNvacc1per, TNvacc1, TNvacc2per, TNvacc2])

# %%
#Texas Cases

#State
TXstate = "TX"

#Cases in the last 7 days
TX7case = "21067"

#Cases in the last 7 days per 100k people
TX7case100 = "072.7"

#Total Cases
TXcase = "4240146"

#Total Cases per 100k people
TXcase100 = "14623"

#Texas Vaccinations

#% with 1 dose
TXvacc1per = "61.66"

#1 dose
TXvacc1 = "17879878"

#% with 2 doses
TXvacc2per = "53.58"

#2 doses
TXvacc2 = "15536798"

#Array of TX data
TX = np.array([TXstate, TX7case, TX7case100, TXcase, TXcase100, TXvacc1per, TXvacc1, TXvacc2per, TXvacc2])

# %%
#Utah Cases

#State
UTstate = "UT"

#Cases in the last 7 days
UT7case = "10722"

#Cases in the last 7 days per 100k people
UT7case100 = "334.4"

#Total Cases
UTcase = "0560604"

#Total Cases per 100k people
UTcase100 = "17486"

#Utah Vaccinations

#% with 1 dose
UTvacc1per = "61.53"

#1 dose
UTvacc1 = "01972624"

#% with 2 doses
UTvacc2per = "54.02"

#2 doses
UTvacc2 = "01731863"

#Array of UT data
UT = np.array([UTstate, UT7case, UT7case100, UTcase, UTcase100, UTvacc1per, UTvacc1, UTvacc2per, UTvacc2])

# %%
#Vermont Cases

#State
VTstate = "VT"

#Cases in the last 7 days
VT7case = "01931"

#Cases in the last 7 days per 100k people
VT7case100 = "309.5"

#Total Cases
VTcase = "0038586"

#Total Cases per 100k people
VTcase100 = "06184"

#Vermont Vaccinations

#% with 1 dose
VTvacc1per = "80.22"

#1 dose
VTvacc1 = "00500553"

#% with 2 doses
VTvacc2per = "71.53"

#2 doses
VTvacc2 = "00446336"

#Array of VT data
VT = np.array([VTstate, VT7case, VT7case100, VTcase, VTcase100, VTvacc1per, VTvacc1, VTvacc2per, VTvacc2])

# %%
#Virginia Cases

#State
VAstate = "VA"

#Cases in the last 7 days
VA7case = "08749"

#Cases in the last 7 days per 100k people
VA7case100 = "102.5"

#Total Cases
VAcase = "0934928"

#Total Cases per 100k people
VAcase100 = "10953"

#Virginia Vaccinations

#% with 1 dose
VAvacc1per = "71.56"

#1 dose
VAvacc1 = "06107963"

#% with 2 doses
VAvacc2per = "63.41"

#2 doses
VAvacc2 = "05412377"

#Array of VA data
VA = np.array([VAstate, VA7case, VA7case100, VAcase, VAcase100, VAvacc1per, VAvacc1, VAvacc2per, VAvacc2])

# %%
#Washington Cases

#State
WAstate = "WA"

#Cases in the last 7 days
WA7case = "12263"

#Cases in the last 7 days per 100k people
WA7case100 = "161.0"

#Total Cases
WAcase = "0737698"

#Total Cases per 100k people
WAcase100 = "09688"

#Washington Vaccinations

#% with 1 dose
WAvacc1per = "69.79"

#1 dose
WAvacc1 = "05314169"

#% with 2 doses
WAvacc2per = "63.80"

#2 doses
WAvacc2 = "04858676"

#Array of WA data
WA = np.array([WAstate, WA7case, WA7case100, WAcase, WAcase100, WAvacc1per, WAvacc1, WAvacc2per, WAvacc2])

# %%
#West Virginia Cases

#State
WVstate = "WV"

#Cases in the last 7 days
WV7case = "05283"

#Cases in the last 7 days per 100k people
WV7case100 = "294.8"

#Total Cases
WVcase = "0276267"

#Total Cases per 100k people
WVcase100 = "15415"

#Vest Virginia Vaccinations

#% with 1 dose
WVvacc1per = "49.11"

#1 dose
WVvacc1 = "00880195"

#% with 2 doses
WVvacc2per = "41.08"

#2 doses
WVvacc2 = "00736199"

#Array of WV data
WV = np.array([WVstate, WV7case, WV7case100, WVcase, WVcase100, WVvacc1per, WVvacc1, WVvacc2per, WVvacc2])

# %%
#Wisconsin Cases

#State
WIstate = "WI"

#Cases in the last 7 days
WI7case = "17190"

#Cases in the last 7 days per 100k people
WI7case100 = "295.2"

#Total Cases
WIcase = "0899647"

#Total Cases per 100k people
WIcase100 = "15451"

#Wisconsin Vaccinations

#% with 1 dose
WIvacc1per = "63.00"

#1 dose
WIvacc1 = "03668056"

#% with 2 doses
WIvacc2per = "58.56"

#2 doses
WIvacc2 = "03409332"

#Array of WI data
WI = np.array([WIstate, WI7case, WI7case100, WIcase, WIcase100, WIvacc1per, WIvacc1, WIvacc2per, WIvacc2])

# %%
#Wyoming Cases

#State
WYstate = "WY"

#Cases in the last 7 days
WY7case = "02392"

#Cases in the last 7 days per 100k people
WY7case100 = "413.3"

#Total Cases
WYcase = "0105318"

#Total Cases per 100k people
WYcase100 = "18197"

#Wyoming Vaccinations

#% with 1 dose
WYvacc1per = "51.33"

#1 dose
WYvacc1 = "00297100"

#% with 2 doses
WYvacc2per = "44.27"

#2 doses
WYvacc2 = "00256237"

#Array of WY data
WY = np.array([WYstate, WY7case, WY7case100, WYcase, WYcase100, WYvacc1per, WYvacc1, WYvacc2per, WYvacc2])

# %%
#Table header
header = np.hstack((np.array(["State"]),np.array(["Cases in Last 7 Days"]),np.array(["Cases in Last 7 Days / 100k People"]),np.array(["Total Cases"]),np.array(["Total Cases / 100k People"]),np.array(["% of People with 1 Dose"]),np.array(["People with 1 Dose"]),np.array(["% of People with 2 Doses"]),np.array(["People with 2 Doses"])))

# %%
#Sorted by state
stateSort = np.vstack((AL,AK,AZ,AR,CA,CO,CT,DE,DC,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI,MN,MS,MO,MT,NE,NV,NH,NJ,NM,NY,NC,ND,OH,OK,OR,PA,RI,SC,SD,TN,TX,UT,VT,VA,WA,WV,WI,WY))

# %%
sortSelect = input("0. State\n1. Cases in Last 7 Days\n2. Cases in Last 7 Days / 100k People\n3. Total Cases\n4. Total Cases / 100k People\n5. % of People with 1 Dose\n6. People with 1 Dose\n7. % of People with 2 Doses\n8. People with 2 Doses\nPlease select how you want to sort the data, using an integer from 0 to 8 inclusive: ")
while sortSelect != "0" and sortSelect != "1" and sortSelect != "2" and sortSelect != "3" and sortSelect != "4" and sortSelect != "5" and sortSelect != "6" and sortSelect != "7" and sortSelect != "8":
    sortSelect = input("Input a number between 0 and 8 inclusive as your selection: ")
# Out:
# 0. State
# 1. Cases in Last 7 Days
# 2. Cases in Last 7 Days / 100k People
# 3. Total Cases
# 4. Total Cases / 100k People
# 5. % of People with 1 Dose
# 6. People with 1 Dose
# 7. % of People with 2 Doses
# 8. People with 2 Doses
# Please select how you want to sort the data, using an integer from 0 to 8 inclusive: 3

# %%
upDownSel = input("Input '0' to sort the data in ascending order. Input '1' to sort the data in descending order: ")
while upDownSel != "0" and upDownSel != "1":
    upDownSel = input("Input '0' or '1' to sort the data in ascending or descending order respectively: ")
# Out:
# Input '0' to sort the data in ascending order. Input '1' to sort the data in descending order: 0

# %%
sortSelect = int(sortSelect)
upDownSel = int(upDownSel)

# %%
sortedTable = stateSort[stateSort[:,sortSelect].argsort()]

# %%
if sortSelect == int(0):
    if upDownSel == int(0):
        display(HTML(tabulate.tabulate(np.vstack((header, stateSort)), tablefmt='html')))
    else:
        display(HTML(tabulate.tabulate(np.vstack((header, np.flipud(stateSort))), tablefmt='html')))
else:
    if upDownSel == int(0):
        display(HTML(tabulate.tabulate(np.vstack((header, stateSort[stateSort[:,sortSelect].argsort()])), tablefmt='html')))
        print("The state with the least " + header[sortSelect] + " is " + sortedTable[0,0] +" with " + sortedTable[0,sortSelect] + ".")
        print("The state with the most " + header[sortSelect] + " is " + np.flipud(sortedTable)[0,0] +" with " + np.flipud(sortedTable)[0,sortSelect] + ".")
    else:
        display(HTML(tabulate.tabulate(np.vstack((header, np.flipud(stateSort[stateSort[:,sortSelect].argsort()]))), tablefmt='html')))
        print("The state with the most " + header[sortSelect] + " is " + np.flipud(sortedTable)[0,0] +" with " + np.flipud(sortedTable)[0,sortSelect] + ".")
        print("The state with the least " + header[sortSelect] + " is " + sortedTable[0,0] +" with " + sortedTable[0,sortSelect] + ".")
print("\nCOVID case data as recent as " + caseDate + ".")
print("COVID vaccine data as recent as " + vaccDate + ".")
# Out:
# <table>
# <tbody>
# <tr><td>State</td><td>Cases in Last 7 Days</td><td>Cases in Last 7 Days / 100k People</td><td>Total Cases</td><td>Total Cases / 100k People</td><td>% of People with 1 Dose</td><td>People with 1 Dose</td><td>% of People with 2 Doses</td><td>People with 2 Doses</td></tr>
# <tr><td>VT   </td><td>01931               </td><td>309.5                             </td><td>0038586    </td><td>06184                    </td><td>80.22                  </td><td>00500553          </td><td>71.53                   </td><td>00446336           </td></tr>
# <tr><td>DC   </td><td>00559               </td><td>079.2                             </td><td>0064799    </td><td>09182                    </td><td>75.64                  </td><td>00533815          </td><td>62.90                   </td><td>00443934           </td></tr>
# <tr><td>HI   </td><td>00760               </td><td>053.7                             </td><td>0082071    </td><td>05796                    </td><td>79.26                  </td><td>01122158          </td><td>60.02                   </td><td>00849770           </td></tr>
# <tr><td>WY   </td><td>02392               </td><td>413.3                             </td><td>0105318    </td><td>18197                    </td><td>51.33                  </td><td>00297100          </td><td>44.27                   </td><td>00256237           </td></tr>
# <tr><td>ME   </td><td>04066               </td><td>302.5                             </td><td>0107737    </td><td>08015                    </td><td>77.36                  </td><td>01039835          </td><td>70.91                   </td><td>00953207           </td></tr>
# <tr><td>AK   </td><td>04177               </td><td>571.0                             </td><td>0136822    </td><td>18703                    </td><td>59.80                  </td><td>00437494          </td><td>52.91                   </td><td>00387028           </td></tr>
# <tr><td>NH   </td><td>04807               </td><td>353.5                             </td><td>0139324    </td><td>10247                    </td><td>78.10                  </td><td>01061907          </td><td>63.25                   </td><td>00859959           </td></tr>
# <tr><td>DE   </td><td>01767               </td><td>181.5                             </td><td>0145330    </td><td>14925                    </td><td>69.52                  </td><td>00676938          </td><td>60.15                   </td><td>00585705           </td></tr>
# <tr><td>ND   </td><td>03553               </td><td>466.2                             </td><td>0151644    </td><td>19899                    </td><td>55.30                  </td><td>00421444          </td><td>47.77                   </td><td>00364057           </td></tr>
# <tr><td>SD   </td><td>02513               </td><td>284.1                             </td><td>0156995    </td><td>17746                    </td><td>62.69                  </td><td>00554587          </td><td>53.19                   </td><td>00470541           </td></tr>
# <tr><td>MT   </td><td>04605               </td><td>430.9                             </td><td>0180452    </td><td>16884                    </td><td>57.27                  </td><td>00612140          </td><td>50.77                   </td><td>00542662           </td></tr>
# <tr><td>RI   </td><td>01653               </td><td>156.0                             </td><td>0181079    </td><td>17093                    </td><td>78.69                  </td><td>00833615          </td><td>71.21                   </td><td>00754331           </td></tr>
# <tr><td>WV   </td><td>05283               </td><td>294.8                             </td><td>0276267    </td><td>15415                    </td><td>49.11                  </td><td>00880195          </td><td>41.08                   </td><td>00736199           </td></tr>
# <tr><td>NM   </td><td>07533               </td><td>359.3                             </td><td>0282742    </td><td>13484                    </td><td>72.63                  </td><td>01522958          </td><td>62.38                   </td><td>01308007           </td></tr>
# <tr><td>NE   </td><td>04516               </td><td>233.5                             </td><td>0289282    </td><td>14954                    </td><td>61.29                  </td><td>01185648          </td><td>56.46                   </td><td>01092256           </td></tr>
# <tr><td>ID   </td><td>05078               </td><td>284.2                             </td><td>0295950    </td><td>16561                    </td><td>49.41                  </td><td>00882949          </td><td>44.16                   </td><td>00789098           </td></tr>
# <tr><td>OR   </td><td>07084               </td><td>168.0                             </td><td>0372137    </td><td>08823                    </td><td>68.69                  </td><td>02897123          </td><td>63.10                   </td><td>02661407           </td></tr>
# <tr><td>CT   </td><td>02386               </td><td>066.9                             </td><td>0404969    </td><td>11359                    </td><td>79.63                  </td><td>02839105          </td><td>70.96                   </td><td>02529755           </td></tr>
# <tr><td>KS   </td><td>05657               </td><td>194.2                             </td><td>0440303    </td><td>15114                    </td><td>62.96                  </td><td>01834175          </td><td>53.45                   </td><td>01557100           </td></tr>
# <tr><td>NV   </td><td>05841               </td><td>189.6                             </td><td>0455163    </td><td>14777                    </td><td>63.77                  </td><td>01964166          </td><td>53.24                   </td><td>01640000           </td></tr>
# <tr><td>IA   </td><td>08275               </td><td>262.3                             </td><td>0494407    </td><td>15670                    </td><td>59.98                  </td><td>01892307          </td><td>55.80                   </td><td>01760389           </td></tr>
# <tr><td>MS   </td><td>02238               </td><td>075.2                             </td><td>0506556    </td><td>17020                    </td><td>52.39                  </td><td>01559285          </td><td>46.01                   </td><td>01369214           </td></tr>
# <tr><td>AR   </td><td>02994               </td><td>099.2                             </td><td>0515524    </td><td>17083                    </td><td>58.32                  </td><td>01760122          </td><td>48.27                   </td><td>01456597           </td></tr>
# <tr><td>UT   </td><td>10722               </td><td>334.4                             </td><td>0560604    </td><td>17486                    </td><td>61.53                  </td><td>01972624          </td><td>54.02                   </td><td>01731863           </td></tr>
# <tr><td>MD   </td><td>04721               </td><td>078.1                             </td><td>0565355    </td><td>09351                    </td><td>73.16                  </td><td>04423295          </td><td>66.17                   </td><td>04000327           </td></tr>
# <tr><td>OK   </td><td>04107               </td><td>103.8                             </td><td>0648791    </td><td>16396                    </td><td>59.94                  </td><td>02371929          </td><td>50.35                   </td><td>01992503           </td></tr>
# <tr><td>WA   </td><td>12263               </td><td>161.0                             </td><td>0737698    </td><td>09688                    </td><td>69.79                  </td><td>05314169          </td><td>63.80                   </td><td>04858676           </td></tr>
# <tr><td>KY   </td><td>07829               </td><td>175.2                             </td><td>0750985    </td><td>16809                    </td><td>57.78                  </td><td>02581520          </td><td>50.96                   </td><td>02276697           </td></tr>
# <tr><td>CO   </td><td>19992               </td><td>347.2                             </td><td>0760453    </td><td>13205                    </td><td>68.01
# The state with the least Total Cases is VT with 0038586.
# The state with the most Total Cases is CA with 4937188.
#
# COVID case data as recent as 11-6-2021.
# COVID vaccine data as recent as 11-5-2021.

# %%
print('1. Cases in last 7 days\n2. Cases in last 7 days per 100k people\n3. Total cases\n4. Total cases per 100k people\n5. % of people with 1 dose\n6. People with 1 dose\n7. % of people with 2 doses\n8. People with 2 doses')
xaxis = int(input('What would like the x-axis to be? (1-8):'))
yaxis = int(input('What would like the y-axis to be? (1-8):'))
# Out:
# 1. Cases in last 7 days
# 2. Cases in last 7 days per 100k people
# 3. Total cases
# 4. Total cases per 100k people
# 5. % of people with 1 dose
# 6. People with 1 dose
# 7. % of people with 2 doses
# 8. People with 2 doses
# What would like the x-axis to be? (1-8):1
# What would like the y-axis to be? (1-8):1

# %%
import matplotlib.pyplot as plt
x = np.sort(stateSort[:,int(xaxis)])
y = np.sort(stateSort[:,int(yaxis)])
plt.figure(figsize=(50, 15))
if xaxis == 1:
    plt.xlabel('Cases in the last 7 days')
if xaxis == 2:
    plt.xlabel('Cases in the last 7 days per 100k people')
if xaxis == 3:
    plt.xlabel('Total Cases')
if xaxis == 4:
    plt.xlabel('Total cases per 100k people')
if xaxis == 5:
    plt.xlabel('% of people with 1 dose')
if xaxis == 6:
    plt.xlabel('People with 1 dose')
if xaxis == 7:
    plt.xlabel('% of people with 2 doses')
if xaxis == 8:
    plt.xlabel('People with 2 doses')
if yaxis == 1:
    plt.ylabel('Cases in the last 7 days')
if yaxis == 2:
    plt.ylabel('Cases in last 7 days per 100k people')
if yaxis == 3:
    plt.ylabel('Total Cases')
if yaxis == 4:
    plt.ylabel('Total cases per 100k people')
if yaxis == 5:
    plt.ylabel('% of people with 1 dose')
if yaxis == 6:
    plt.ylabel('People with 1 dose')
if yaxis == 7:
    plt.ylabel('% of people with 2 doses')
if yaxis == 8:
    plt.ylabel('People with 2 doses')
display(plt.plot(x, y, 'o'))
# Out:
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
